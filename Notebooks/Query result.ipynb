# %%
# %sql
SHOW SCHEMAS IN maritime_ais;

# %%
# %sql
SELECT mmsi, vessel_name, recorded_at, latitude, longitude, speed_over_ground, course_over_ground, heading
FROM maritime_ais.maritime_gold.vessel_trajectory
WHERE speed_over_ground > 0
ORDER BY mmsi, timestamp;
# Out:
# Databricks visualization. Run in Databricks to view.
